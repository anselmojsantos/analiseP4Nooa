# %%
import os
import pandas as pd
from sqlalchemy import create_engine, inspect

# %%
dadosUrl = "postgresql://noaa_user:C53AONMRWKIZ3nlrVkQPpGMVmWjNNpyu@dpg-da6a5oqjnfac73aajj5g-a.oregon-postgres.render.com/noaa?sslmode=require"

# %%
engine = create_engine(dadosUrl)
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['ana_telemetry_reading', 'cemaden_sensor', 'cemaden_station', 'cemaden_reading', 'noaa_enso_weekly', 'ana_station']

# %%
df = pd.read_sql("SELECT * FROM cemaden_sensor", engine)
df.isna().sum()
# Out:
# id              0
# description     0
# collected_at    0
# updated_at      0
# dtype: int64

# %%
df
# Out:
#      id                                     description  \
# 0   430          Direção do Vento Predominante - Diária
# 1   440     Temperatura do Solo Nível 1 Máxima - Diária
# 2   450     Temperatura do Solo Nível 1 Mínima - Diária
# 3   460     Temperatura do Solo Nível 2 Máxima - Diária
# 4   470     Temperatura do Solo Nível 2 Mínima - Diária
# 5   480     Temperatura do Solo Nível 3 Máxima - Diária
# 6   490     Temperatura do Solo Nível 3 Mínima - Diária
# 7   500     Temperatura do Solo Nível 4 Máxima - Diária
# 8   510     Temperatura do Solo Nível 4 Mínima - Diária
# 9   560         Umidade do Solo Nível 3 Máxima - Diária
# 10  570         Umidade do Solo Nível 3 Mínima - Diária
# 11  580         Umidade do Solo Nível 4 Máxima - Diária
# 12  590         Umidade do Solo Nível 4 Mínima - Diária
# 13  610                         Umidade do Solo Nível 5
# 14  620                         Umidade do Solo Nível 6
# 15  630         Umidade do Solo Nível 5 Máxima - Diária
# 16  640         Umidade do Solo Nível 5 Mínima - Diária
# 17  650         Umidade do Solo Nível 6 Máxima - Diária
# 18  660         Umidade do Solo Nível 6 Mínima - Diária
# 19   10                                           Chuva
# 20  240                     Intensidade da Precipitação
# 21  330                         Umidade do Solo Nível 1
# 22  340                         Umidade do Solo Nível 2
# 23  520         Umidade do Solo Nível 1 Máxima - Diária
# 24  530         Umidade do Solo Nível 1 Mínima - Diária
# 25  540         Umidade do Solo Nível 2 Máxima - Diária
# 26  550         Umidade do Solo Nível 2 Mínima - Diária
# 27  600                 Precipitação Acumulada - Diária
# 28   20                                           Nível
# 29  260                                    Nível Mínimo
# 30  270                                    Nível Máximo
# 31   60                               Temperatura do Ar
# 32   90                          Umidade Relativa do Ar
# 33  180                             Velocidade do Vento
# 34  190                                Direção do Vento
# 35  210                                  Radiação Solar
# 36  280                                  Saldo Radiação
# 37  290                     Temperatura do Solo Nível 1
# 38  300                     Temperatura do Solo Nível 2
# 39  310                     Temperatura do Solo Nível 3
# 40  320                     Temperatura do Solo Nível 4
# 41  350                         Umidade do Solo Nível 3
# 42  360                         Umidade do Solo Nível 4
# 43  370               Temperatura Máxima do Ar - Diária
# 44  390          Umidade Relativa Máxima do Ar - Diária
# 45  400          Umidade Relativa Mínima do Ar - Diária
# 46  410             Velocidade do Vento Máxima - Diária
# 47  420  Direção do Vento na Velocidade Máxima - Diária
#
#               collected_at              updated_at
# 0  2026-08-28 18:17:43.617 2026-09-15 17:51:44.976
# 1  2026-08-28 18:17:43.822 2026-09-15 17:51:45.179
